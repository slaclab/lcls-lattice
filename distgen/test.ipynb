# %%
from distgen import Generator
import yaml

G = Generator('models/cu_inj/distgen.yaml')
G.run()

# %%
G = Generator('models/gunb_gaussian/distgen.yaml')
G.run()

# %%
G = Generator('models/sc_inj/distgen.yaml')
G.run()
