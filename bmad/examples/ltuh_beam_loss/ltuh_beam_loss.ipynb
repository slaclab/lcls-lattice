# %% [markdown]
# # LTHU beam loss
#
# This script shows how a beam loss can be specified at a particular s location.
#
# It is somewhat hackey, using the unstable.orbit datum which wants a relative index for the loss point.

# %%
# Useful for debugging
#%load_ext autoreload
#%autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %config InlineBackend.figure_format = 'retina'

from pytao import TaoModel

# %%
# Load model
M = TaoModel('$LCLS_LATTICE/bmad/examples/ltuh_beam_loss/tao.init', ploton=True)
# Out:
# Initialized Tao with /var/folders/wj/lfgr01993dx79p9cm_skykbw0000gn/T/tmpmgpcj3i7/tao/tao.init

# %%
# Get info to lookup indices

# Helper function
def lat_names(match='*'):
    return np.array(M.cmd(f'python lat_list -track_only >>{match}|model ele.name'))

ELE_S = np.array(M.cmd('python lat_list -track_only >>*|model ele.s')).astype('float')



ELE_NAMES = lat_names().tolist()
END_ELE = ELE_NAMES[-1]
IX_REF = ELE_NAMES.index(END_ELE)
S_REF = ELE_S[IX_REF]

# Get floor Z
FLOOR_Z = np.array(M.evaluate(f'lat::floor.z[beginning:{END_ELE}]'))

MIN_Z = FLOOR_Z[0]
MAX_Z = FLOOR_Z[-1]

END_ELE, ELE_NAMES.index(END_ELE)
# Out:
# ('DTDUND2', 2213)

# %%
# Z range
FLOOR_Z[0], FLOOR_Z[-1]
# Out:
# (3224.76242303644, 3561.33382646054)

# %%
# Simple helper function
def s_from_z(z):
    """
    Floor Z from s
    """
    
    if z < MIN_Z:
        raise ValueError(f'Error: Z = {z} is less than the minumum {MIN_Z}')
        
    if z > MAX_Z:
        raise ValueError(f'Error: Z = {z} is greater than the maximum {MAX_Z}')        
    
    return np.interp(z, FLOOR_Z, ELE_S)


s_from_z(3300)
# Out:
# 1285.3385798036663

# %%
# Use all correctors. There should only be one datum: loss.rel_point
M.cmd('use var xcors')
M.cmd('sho dat')
# Out:
# ['',
#  '  Name                                 Using for Optimization',
#  '  aperture.p[0:893]                              Using:',
#  '  aperture.n[0:893]                              Using:',
#  '  orbit.x[1:29]                                  Using:',
#  '  orbit.y[1:0]                                   Using:',
#  '  orbit.profx[1:0]                               Using:',
#  '  orbit.profy[1:0]                               Using:',
#  '  orbit.e[1:0]                                   Using:',
#  '  loss[1:1]                                      Using: 1']

# %%
def set_loss_s(s):
    """
    Sets the appropriate loss 
    """
    M.cmd(f'set dat loss.rel_point|ele_name ={END_ELE}')
        
    ix_target = np.abs(ELE_S-s).argmin()
    
    M.cmd(f'set dat loss.rel_point|meas ={IX_REF-ix_target}')
    return ELE_S[ix_target], ELE_NAMES[ix_target]

# Similar to above, but for z
def set_loss_z(z):
    
    s = s_from_z(z)
    print(f'Setting loss at s = {s} m, Z = {z} m')
    return set_loss_s(s)

set_loss_s(1280)
set_loss_z(3400)
# Out:
# Setting loss at s = 1385.345074975222 m, Z = 3400 m
# (1385.35007502969, 'DMM1M90CM#7')

# %%
# Reset lattice
M.cmd('set lattice model=design')
# Out:
# []

# %%
# Turn off collimators
M.cmd('set ele rcoll::* x1_limit = 20e-3')
M.cmd('set ele rcoll::* x2_limit = 20e-3')
# Out:
# []

# %%
# Use the DE optimizer - it has enough noise to seed a loss
# Play with these numbers to make it faster/more accurate
M.cmd('scycles 2')
M.cmd('sde 1000')
M.cmd('ode')
# Out:
# []

# %%
def try_loss_z(zloss):
    set_loss_z(zloss)
    M.cmd('run')
    ix_loss = int(IX_REF - M.evaluate('data::loss.rel_point[1]|model'))
    s_lost_actual = ELE_S[ix_loss]
    z_loss_actual = FLOOR_Z[ix_loss]
    print(f'Actual loss at s = {s_lost_actual} m, Z = {z_loss_actual} m')
    return z_loss_actual
try_loss_z(3500)
# Out:
# Setting loss at s = 1485.3461647364356 m, Z = 3500 m
# Actual loss at s = 1487.12018406879 m, Z = 3501.77399999999 m
# 3501.77399999999

# %%
# Try one place at s
set_loss_s(1460)
M.cmd('run');

# %%
# Loop over some loss points in Z
Z_TRY = np.linspace(MAX_Z,MIN_Z,20)
Z_ACTUAL = []
for zloss in Z_TRY:
    zact = try_loss_z(zloss)
    Z_ACTUAL.append(zact)
# Out:
# Setting loss at s = 1546.68065958926 m, Z = 3561.33382646054 m
# Actual loss at s = 1462.10891150861 m, Z = 3476.76299999999 m
# Setting loss at s = 1528.9661821550883 m, Z = 3543.6195420697977 m
# Actual loss at s = 1480.76012676011 m, Z = 3495.41401199999 m
# Setting loss at s = 1511.2517047209496 m, Z = 3525.905257679056 m
# Actual loss at s = 1489.05469608926 m, Z = 3503.70849093913 m
# Setting loss at s = 1493.5372272867994 m, Z = 3508.1909732883137 m
# Actual loss at s = 1489.2532073134 m, Z = 3503.90699999999 m
# Setting loss at s = 1475.822749852658 m, Z = 3490.4766888975714 m
# Actual loss at s = 1489.2532073134 m, Z = 3503.90699999999 m
# Setting loss at s = 1458.1082724185162 m, Z = 3472.7624045068296 m
# Actual loss at s = 1454.04982368476 m, Z = 3468.70399999999 m
# Setting loss at s = 1440.3937949843678 m, Z = 3455.0481201160874 m
# Actual loss at s = 1450.26678245909 m, Z = 3464.92099999999 m
# Setting loss at s = 1422.6793175502319 m, Z = 3437.333835725345 m
# Actual loss at s = 1442.97270297191 m, Z = 3457.62699999999 m
# Setting loss at s = 1404.9648401160846 m, Z = 3419.619551334603 m
# Actual loss at s = 1407.61231763234 m, Z = 3422.26699999999 m
# Setting loss at s = 1387.2503626819478 m, Z = 3401.905266943861 m
# Actual loss at s = 1390.66213291781 m, Z = 3405.31699999999 m
# Setting loss at s = 1369.5358852477996 m, Z = 3384.190982553119 m
# Actual loss at s = 1380.79370137664 m, Z = 3395.44867599999 m
# Setting loss at s = 1351.8214078136507 m, Z = 3366.4766981623766 m
# Actual loss at s = 1345.82262226359 m, Z = 3360.47799999999 m
# Setting loss at s = 1334.1066106421222 m, Z = 3348.762413771635 m
# Actual loss at s = 1326.8058393226 m, Z = 3341.462 m
# Setting loss at s = 1316.3914586697547 m, Z = 3331.0481293808925 m
# Actual loss at s = 1326.8058393226 m, Z = 3341.462 m
# Setting loss at s = 1298.6746012400963 m, Z = 3313.3338449901503 m
# Actual loss at s = 1293.2508710941 m, Z = 3307.91099999999 m
# Setting loss at s = 1280.957425396176 m, Z = 3295.6195605994085 m
# Actual loss at s = 1278.03736386145 m, Z = 3292.70000992197 m
# Setting loss at s = 1263.241078927121 m, Z = 3277.9052762086662 m
# Actual loss at s = 1272.74648073941 m, Z = 3287.40999999999 m
# Setting loss at s = 1245.5259269547528 m, Z = 3260.190991817924 m
# Actual loss at s = 1272.74648073941 m, Z = 3287.40999999999 m
# Setting loss at s = 1227.8114106347564 m, Z = 3242.476707427182 m
# Actual loss at s = 1272.74648073941 m, Z = 3287.40999999999 m
# Setting loss at s = 1210.09708508099 m, Z = 3224.76242303644 m
# Actual loss at s = 1272.74648073941 m, Z = 3287.40999999999 m

# %%
plt.xlabel('Z try (m)')
plt.ylabel('Z actual (m)')
plt.plot(Z_TRY, Z_ACTUAL)

# %%
plt.title('Error in loss attempt')
plt.xlabel('Z try (m)')
plt.ylabel('Z actual - try (m)')
plt.scatter(Z_TRY, Z_ACTUAL- Z_TRY)
