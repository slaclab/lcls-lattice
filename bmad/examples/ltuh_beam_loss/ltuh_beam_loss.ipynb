# %% [markdown]
# # LTHU beam loss
#
# This script shows how a beam loss can be specified at a particular s location.
#
# It is somewhat hackey, using the unstable.orbit datum which wants a relative index for the loss point.

# %%
# Useful for debugging
#%load_ext autoreload
#%autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %config InlineBackend.figure_format = 'retina'

from pytao import Tao

# %%
# Load model
tao = Tao('-init $LCLS_LATTICE/bmad/examples/ltuh_beam_loss/tao.init')

# %%
# Get info to lookup indices
ELE_NAMES = tao.lat_list('*', 'ele.name');
ELE_S = tao.lat_list('*', 'ele.s');


#ELE_NAMES = lat_names().tolist()
END_ELE = ELE_NAMES[-1]
IX_REF = ELE_NAMES.index(END_ELE)
S_REF = ELE_S[IX_REF]

# Get floor Z
FLOOR_Z = np.array(tao.evaluate(f'lat::floor.z[beginning:{END_ELE}]'))

MIN_Z = FLOOR_Z[0]
MAX_Z = FLOOR_Z[-1]

END_ELE, ELE_NAMES.index(END_ELE)
# Out:
# ('DTDUND2', 2215)

# %%
# Z range
FLOOR_Z[0], FLOOR_Z[-1]
# Out:
# (3224.7624230364427, 3561.3338264605427)

# %%
# Simple helper function
def s_from_z(z):
    """
    Floor Z from s
    """
    
    if z < MIN_Z:
        raise ValueError(f'Error: Z = {z} is less than the minumum {MIN_Z}')
        
    if z > MAX_Z:
        raise ValueError(f'Error: Z = {z} is greater than the maximum {MAX_Z}')        
    
    return np.interp(z, FLOOR_Z, ELE_S)


s_from_z(3300)
# Out:
# 1285.3385793884534

# %%
# Use all correctors. There should only be one datum: loss.rel_point
tao.cmd('use var xcor')
tao.cmd('set var xcor|meas =0') 
tao.cmd('set var xcor|weight =1e8')
tao.cmd('use dat loss.rel_point')
tao.cmd('set dat loss.rel_point|weight = 1')
tao.cmd('sho dat')
# Out:
# ['',
#  '  Name                                 Using for Optimization',
#  '  orbit.x[1:29]                                  Using:',
#  '  orbit.y[1:0]                                   Using:',
#  '  orbit.profx[1:0]                               Using:',
#  '  orbit.profy[1:0]                               Using:',
#  '  orbit.e[1:0]                                   Using:',
#  '  loss[1:1]                                      Using: 1']

# %%
def set_loss_s(s):
    """
    Sets the appropriate loss s position
    """
    tao.cmd(f'set dat loss.rel_point|ele_name ={END_ELE}')
        
    ix_target = np.abs(ELE_S-s).argmin()
    
    tao.cmd(f'set dat loss.rel_point|meas ={IX_REF-ix_target}')
    return ELE_S[ix_target], ELE_NAMES[ix_target]

def set_loss_z(z):
    """
    Sets the appropriate loss z position
    """
    s = s_from_z(z)
    print(f'Setting loss at s = {s} m, Z = {z} m')
    return set_loss_s(s)

set_loss_s(1280)
set_loss_z(3400)
# Out:
# Setting loss at s = 1385.3450745600092 m, Z = 3400 m
# (1385.3500746144814, 'DMM1M90CM#7')

# %%
# Reset lattice
def reset():
    tao.cmd('set lattice model=design')
    # Turn off collimators
    tao.cmd('set ele rcoll::* x1_limit = 20e-3')
    tao.cmd('set ele rcoll::* x2_limit = 20e-3')    
reset()

# %%
# Use the DE optimizer - it has enough noise to seed a loss
# Play with these numbers to make it faster/more accurate
tao.cmd('scycles 5')
tao.cmd('sde 1000')
tao.cmd('ode')
#M.cmd('olmdif')
# Out:
# []

# %%
def try_loss_z(zloss):
    #reset()
    set_loss_z(zloss)
    tao.cmd('run', raises=False)
    ix_loss = int(IX_REF - tao.evaluate('data::loss.rel_point[1]|model'))
    s_lost_actual = ELE_S[ix_loss]
    z_loss_actual = FLOOR_Z[ix_loss]
    print(f'Actual loss at s = {s_lost_actual} m, Z = {z_loss_actual} m')
    return z_loss_actual

# %%
# Try one place at s
try_loss_z(3500)
# Out:
# Setting loss at s = 1485.3461643212272 m, Z = 3500 m
#  tao_de_optimizer merit for rank    1358.6396077841744                0
# Actual loss at s = 1489.2532068981839 m, Z = 3503.906999999986 m
# 3503.906999999986

# %%
# Loop over some loss points in Z
Z_TRY = np.linspace(MAX_Z,MIN_Z,20)
Z_ACTUAL = []
for zloss in Z_TRY:
    zact = try_loss_z(zloss)
    Z_ACTUAL.append(zact)
# Out:
# Setting loss at s = 1546.6806591740499 m, Z = 3561.3338264605427 m
#  tao_de_optimizer merit for rank    423.20545129825501                0
# Actual loss at s = 1546.6806591740499 m, Z = 3561.3338264605427 m
# Setting loss at s = 1528.9661817398803 m, Z = 3543.6195420698004 m
#  tao_de_optimizer merit for rank    7270.5895339814342                0
# Actual loss at s = 1541.8297798510393 m, Z = 3556.482999999984 m
# Setting loss at s = 1511.251704305737 m, Z = 3525.9052576790586 m
#  tao_de_optimizer merit for rank    3650.1462478180370                0
# Actual loss at s = 1516.1064995317654 m, Z = 3530.7599999999884 m
# Setting loss at s = 1493.5372268715944 m, Z = 3508.1909732883164 m
#  tao_de_optimizer merit for rank    2509.4950733362884                0
# Actual loss at s = 1489.2532068981839 m, Z = 3503.906999999986 m
# Setting loss at s = 1475.82274943745 m, Z = 3490.476688897574 m
#  tao_de_optimizer merit for rank    4208.9308989884648                0
# Actual loss at s = 1487.120183653578 m, Z = 3501.773999999987 m
# Setting loss at s = 1458.1082720033062 m, Z = 3472.7624045068324 m
#  tao_de_optimizer merit for rank    1916.7507185877530                0
# Actual loss at s = 1462.1089110934017 m, Z = 3476.76299999999 m
# Setting loss at s = 1440.3937945691616 m, Z = 3455.04812011609 m
#  tao_de_optimizer merit for rank    3851.8718699080287                0
# Actual loss at s = 1444.7237216384146 m, Z = 3459.377999999991 m
# Setting loss at s = 1422.6793171350175 m, Z = 3437.333835725348 m
#  tao_de_optimizer merit for rank    6179.0557164621887                0
# Actual loss at s = 1436.480631809393 m, Z = 3451.134999999987 m
# Setting loss at s = 1404.9648397008748 m, Z = 3419.6195513346056 m
#  tao_de_optimizer merit for rank    9087.8019312375054                0
# Actual loss at s = 1390.662132502599 m, Z = 3405.3169999999864 m
# Setting loss at s = 1387.2503622667332 m, Z = 3401.905266943864 m
#  tao_de_optimizer merit for rank    4855.4754188940187                0
# Actual loss at s = 1390.662132502599 m, Z = 3405.3169999999864 m
# Setting loss at s = 1369.5358848325882 m, Z = 3384.1909825531216 m
#  tao_de_optimizer merit for rank    5062.1235352503118                0
# Actual loss at s = 1380.2110186116533 m, Z = 3394.8659999999863 m
# Setting loss at s = 1351.8214073984436 m, Z = 3366.4766981623793 m
#  tao_de_optimizer merit for rank    4567.2281418764833                0
# Actual loss at s = 1348.4816521320972 m, Z = 3363.137001052777 m
# Setting loss at s = 1334.1066102269124 m, Z = 3348.7624137716375 m
#  tao_de_optimizer merit for rank    10111.256859244017                0
# Actual loss at s = 1344.9382882113564 m, Z = 3359.593675999991 m
# Setting loss at s = 1316.3914582545444 m, Z = 3331.0481293808953 m
#  tao_de_optimizer merit for rank    7533.1031541069851                0
# Actual loss at s = 1326.8058389073892 m, Z = 3341.4619999999954 m
# Setting loss at s = 1298.674600824889 m, Z = 3313.333844990153 m
#  tao_de_optimizer merit for rank    6204.1536845010951                0
# Actual loss at s = 1293.2508706788842 m, Z = 3307.910999999993 m
# Setting loss at s = 1280.9574249809727 m, Z = 3295.619560599411 m
#  tao_de_optimizer merit for rank    5875.6126804230680                0
# Actual loss at s = 1278.0373634462367 m, Z = 3292.700009921971 m
# Setting loss at s = 1263.2410785119203 m, Z = 3277.905276208669 m
#  tao_de_optimizer merit for rank    9325.4830688967268                0
# Actual loss at s = 1273.3292514327752 m, Z = 3287.99267599999 m
# Setting loss at s = 1245.5259265395516 m, Z = 3260.1909918179267 m
#  tao_de_optimizer merit for rank    33164.857277981500                0
# Actual loss at s = 1272.7464803241955 m, Z = 3287.409999999986 m
# Setting loss at s = 1227.811410219544 m, Z = 3242.476707427185 m
#  tao_de_optimizer merit for rank    107679.41962717878                0
# Actual loss at s = 1272.7464803241955 m, Z = 3287.409999999986 m
# Setting loss at s = 1210.097084665773 m, Z = 3224.7624230364427 m
#  tao_de_optimizer merit for rank    213351.41962717878                0
# Actual loss at s = 1272.7464803241955 m, Z = 3287.409999999986 m

# %%
plt.xlabel('Z try (m)')
plt.ylabel('Z actual (m)')
plt.plot(Z_TRY, Z_ACTUAL)

# %%
plt.title('Error in loss attempt')
plt.xlabel('Z try (m)')
plt.ylabel('Z actual - try (m)')
plt.scatter(Z_TRY, Z_ACTUAL- Z_TRY)
